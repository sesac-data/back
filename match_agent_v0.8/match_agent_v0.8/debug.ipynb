# %%
import ast; content = open('analyzer.py', encoding='utf-8').read(); tree = ast.parse(content); [print('인자:', [a.arg for a in node.args.args]) for node in ast.walk(tree) if isinstance(node, ast.FunctionDef) and node.name == 'analyze_all_incentives']
# Out:
# 인자: ['biz_info', 'hr_info', 'vat_info']
# [None]
